# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
print os.getcwd()
# %matplotlib inline
# Out:
# /Users/efrainolivares/sandbox/url_filter_with_staffing

# %%
from mpld3 import enable_notebook
enable_notebook()

# %%
# Draw lines
fig, ax = plt.subplots()
x = np.linspace(-5, 15, 1000)
for offset in np.linspace(0, 3, 4):
    ax.plot(x, 0.9 * np.sin(x - offset), lw=5, alpha=0.4,
            label="Offset: {0}".format(offset))
ax.set_xlim(0, 10)
ax.set_ylim(-1.2, 1.0)
ax.text(5, -1.1, "Here are some curves", size=18, ha='center')
ax.grid(color='lightblue', alpha=0.7)
ax.legend()

# %%
fig, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(size=(2, 200))
color, size = np.random.random((2, 200))

ax.scatter(x, y, c=color, s=500 * size, alpha=0.3)
ax.grid(color='lightgray', alpha=0.7)

# %%
fig, ax = plt.subplots(3, 3, figsize=(6, 6),
sharex=True, sharey=True)
fig.subplots_adjust(hspace=0.3)
X[::2,2] += 3
for i in range(3):
    for j in range(3):
        ax[i,j].scatter(X[:,i], X[:,j], c=color, s=.1*size, alpha=0.5, linewidths=2)
        ax[i,j].grid(color='lightblue', alpha=0.7)

# %%
import bokeh.plotting as bkh
bkh.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b6f990c1-7deb-4818-9308-3aa6ee56a52f">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0., 1., 100)
y = np.cumsum(np.random.randn(100))

# %%
from bokeh.plotting import figure, output_file, show


p = figure(plot_width=600, plot_height=400)

# add a line renderer
p.line(x, y, line_width=2)

bkh.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="63a4a188-6f65-4983-90e9-49624d6e210d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("63a4a188-6f65-4983-90e9-49624d6e210d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("63a4a188-6f65-4983-90e9-49624d6e210d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '63a4a188-6f65-4983-90e9-49624d6e210d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"014d12c1-df01-4c46-96f2-1081e0e7a889":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"818f760c-a7b5-4b8a-a876-776f9b25ed9a","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"088f6ba0-1ad2-436e-9218-19ca946be03a","type":"ColumnDataSource"},{"attributes":{},"id":"48a7d0d9-0af8-4ad4-a9f5-00de61e90e8a","type":"LinearScale"},{"attributes":{},"id":"4e923e50-862b-4abf-a56a-07d2adceee5e","type":"LinearScale"},{"attributes":{},"id":"5637094a-4f4e-4fa2-b01f-1b4ca377734a","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"9e96da1f-8248-486c-9d87-f73dd8b27439","type":"BoxAnnotation"},"plot":{"id":"b3b02f82-f7f6-46e8-97c3-42e321107564","subtype":"Figure","type":"Plot"}},"id":"1a44cfbf-f547-412e-8cfc-1d227e12884f","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"812137b8-7bd7-4856-8883-b4a3370bef58","type":"PanTool"},{"id":"ea54a98a-fd64-4e83-96b2-fd4deb8f1306","type":"WheelZoomTool"},{"id":"1a44cfbf-f547-412e-8cfc-1d227e12884f","type":"BoxZoomTool"},{"id":"2747d80b-3199-456b-850d-d19ebc6e974a","type":"SaveTool"},{"id":"d740780f-8342-4955-b6d3-e8e02b1a7900","type":"ResetTool"},{"id":"4cef8189-b4cb-4b64-87c4-05ad4be342dd","type":"HelpTool"}]},"id":"bb009332-1fb5-416f-9601-a76c29ec760a","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"b3b02f82-f7f6-46e8-97c3-42e321107564","subtype":"Figure","type":"Plot"},"ticker":{"id":"deb4209e-c030-4d1d-a918-7a66f07ec90a","type":"BasicTicker"}},"id":"9627bd3d-6737-4076-b0fc-a72ae8904ea5","type":"Grid"},{"attributes":{},"id":"3b1aa74f-4059-495a-a029-264cdfa3c07f","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"69718435-110c-4a8d-805e-cd243d2aa175","type":"Line"},{"attributes":{},"id":"0665eaf9-33c6-4a54-81aa-7ac2d4ebdcfd","type":"BasicTickFormatter"},{"attributes":{},"id":"deb4209e-c030-4d1d-a918-7a66f07ec90a","type":"BasicTicker"},{"attributes":{"plot":{"id":"b3b02f82-f7f6-46e8-97c3-42e321107564","subtype":"Figure","type":"Plot"}},"id":"d740780f-8342-4955-b6d3-e8e02b1a7900","type":"ResetTool"},{"attributes":{"plot":{"id":"b3b02f82-f7f6-46e8-97c3-42e321107564","subtype":"Figure","type":"Plot"}},"id":"ea54a98a-fd64-4e83-96b2-fd4deb8f1306","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"5637094a-4f4e-4fa2-b01f-1b4ca377734a","type":"BasicTickFormatter"},"plot":{"id":"b3b02f82-f7f6-46e8-97c3-42e321107564","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b1aa74f-4059-495a-a029-264cdfa3c07f","type":"BasicTicker"}},"id":"74a015c7-869c-4c41-aa2e-b6ebedcc99ec","type":"LinearAxis"},{"attributes":{"plot":{"id":"b3b02f82-f7f6-46e8-97c3-42e321107564","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b1aa74f-4059-495a-a029-264cdfa3c07f","type":"BasicTicker"}},"id":"80ff9334-6106-4b4d-93a4-0a4f21ed9287","type":"Grid"},{"attributes":{"callback":null},"id":"57982cfa-7be8-47c4-ad0d-b9eb65d6e9cf","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c8a5f709-dbfe-4953-86b6-1e5f287e4565","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9e96da1f-8248-486c-9d87-f73dd8b27439","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"088f6ba0-1ad2-436e-9218-19ca946be03a","type":"ColumnDataSource"},"glyph":{"id":"69718435-110c-4a8d-805e-cd243d2aa175","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph" ...

# %%
import seaborn as sns
x1 = np.random.randn(80)
x2 = np.random.randn(80)
x3 = x1 * x2
y1 = .5 + 2 * x1 - x2 + 2.5 * x3 + 3 * np.random.randn(80)
y2 = .5 + 2 * x1 - x2 + 2.5 * np.random.randn(80)
y3 = y2 + np.random.randn(80)

# %%
sns.violinplot([x1,x2,x3])

# %%
sns.regplot(x2,y2)

# %%
import pandas as pd
df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3, y1=y1, y2=y2, y3=y3))
sns.corrplot(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-345abde5ce5e> in <module>()
#       1 import pandas as pd
#       2 df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3, y1=y1, y2=y2, y3=y3))
# ----> 3 sns.corrplot(df)
#
# AttributeError: 'module' object has no attribute 'corrplot'

# %%
np.random.seed(12)
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
    plt.plot(x, y, label=str(i))
plt.legend()

# %%
import prettyplotlib as ppl
np.random.seed(12)
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
    ppl.plot(x, y, label=str(i))
ppl.legend()
# Out:
# /Users/efrainolivares/envnltk/lib/python2.7/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
